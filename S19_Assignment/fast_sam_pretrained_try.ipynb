# %%
# %%capture
# !git clone https://github.com/CASIA-IVA-Lab/FastSAM.git

# %%
# %%capture
# !wget https://huggingface.co/spaces/An-619/FastSAM/resolve/main/weights/FastSAM.pt

# %%
# %%capture
# !pip install -r FastSAM/requirements.txt
# !pip install git+https://github.com/openai/CLIP.git

# %%
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('/content/FastSAM/examples/dogs.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

original_h = image.shape[0]
original_w = image.shape[1]
print(original_w, original_h)
plt.figure(figsize=(10, 10))
plt.imshow(image)
# Out:
# 1072 603

# %%
# Text prompt
# !python FastSAM/Inference.py --model_path FastSAM.pt --img_path /content/FastSAM/examples/dogs.jpg  --text_prompt "the  dog"

image = cv2.imread('/content/FastSAM/output/dogs.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
original_h = image.shape[0]
original_w = image.shape[1]
print(original_w, original_h)
plt.figure(figsize=(10, 10))
plt.axis("off")
plt.imshow(image)
# Out:
# 0: 576x1024 21 objects, 8178.4ms
# Speed: 3.8ms preprocess, 8178.4ms inference, 155.1ms postprocess per image at shape (1, 3, 1024, 1024)
# 775 435
